# %%
import pandas as pd
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import scipy

# %%
#Load CSV
data_raw_csv = Path("Resources/dog_data.csv")

#Read CSV
raw_data_df = pd.read_csv(data_raw_csv)
raw_data_df.head()
# Out:
#          Dog breed  Unnamed: 1                    category  Unnamed: 3  \
# 0  Additional info         NaN  American Kennel Club group         NaN
# 1    Border Collie         NaN                     herding         NaN
# 2   Border Terrier         NaN                     terrier         NaN
# 3         Brittany         NaN                    sporting         NaN
# 4    Cairn Terrier         NaN                     terrier         NaN
#
#    datadog score                                   POPULARITY IN US  \
# 0            NaN  1- 173, 1 = most poular, US. American Kennel C...
# 1           3.64                                                 45
# 2           3.61                                                 80
# 3           3.54                                                 30
# 4           3.53                                                 59
#
#                           POPULARITY IN US.1 LIFETIME COST, $  \
# 0  ranking within breeds with full data only              NaN
# ...

# %%
#drop the top row
raw_data_df = raw_data_df.drop(labels=0, axis=0)
raw_data_df.head(5)
# Out:
#                 Dog breed  Unnamed: 1  category  Unnamed: 3  datadog score  \
# 1           Border Collie         NaN   herding         NaN           3.64
# 2          Border Terrier         NaN   terrier         NaN           3.61
# 3                Brittany         NaN  sporting         NaN           3.54
# 4           Cairn Terrier         NaN   terrier         NaN           3.53
# 5  Welsh Springer Spaniel         NaN  sporting         NaN           3.34
#
#   POPULARITY IN US POPULARITY IN US.1 LIFETIME COST, $ 5 LIFETIME COST  \
# 1               45                 39          $20,143             48%
# 2               80                 61          $22,638             14%
# 3               30                 30          $22,589             16%
# 4               59                 48          $21,992             22%
# 5              130                 81          $20,224             47%
#
#    Unnamed: 9  ... Unnamed: 59 Other regular costs, total per lifetime, $  \
# ...

# %%
#drop column
raw_data_df = raw_data_df.drop(columns = ['Unnamed: 1','Unnamed: 3','Unnamed: 9','Unnamed: 59'])
raw_data_df.head()
# Out:
#                 Dog breed  category  datadog score POPULARITY IN US  \
# 1           Border Collie   herding           3.64               45
# 2          Border Terrier   terrier           3.61               80
# 3                Brittany  sporting           3.54               30
# 4           Cairn Terrier   terrier           3.53               59
# 5  Welsh Springer Spaniel  sporting           3.34              130
#
#   POPULARITY IN US.1 LIFETIME COST, $ 5 LIFETIME COST  \
# 1                 39          $20,143             48%
# 2                 61          $22,638             14%
# 3                 30          $22,589             16%
# 4                 48          $21,992             22%
# 5                 81          $20,224             47%
#
#   1 INTELLIGENCE (TRAINABILITY) ranking INTELLIGENCE (TRAINABILITY) ranking  \
# 1                                     1                                100%
# ...

# %%
# drop column
raw_data_df = raw_data_df.drop(columns = ['5 LIFETIME COST','INTELLIGENCE (TRAINABILITY) ranking','GENETIC AILMENTS','food costs per year, US$','ULTIMATE TOP DOG MEGA SCORE (with kids)','ULTIMATE TOP DATA DOG MEGA RANKING - without kids','ULTIMATE TOP DATA DOG MEGA RANKING - with kids','ULTIMATE TOP DOG MEGA SCORE',
                                          'weight (kg)','weight (lbs)','shoulder height (cm)','shoulder height (in)','note'])
raw_data_df.head()
# Out:
#                 Dog breed  category  datadog score POPULARITY IN US  \
# 1           Border Collie   herding           3.64               45
# 2          Border Terrier   terrier           3.61               80
# 3                Brittany  sporting           3.54               30
# 4           Cairn Terrier   terrier           3.53               59
# 5  Welsh Springer Spaniel  sporting           3.34              130
#
#   POPULARITY IN US.1 LIFETIME COST, $ 1 INTELLIGENCE (TRAINABILITY) ranking  \
# 1                 39          $20,143                                     1
# 2                 61          $22,638                                    30
# 3                 30          $22,589                                    19
# 4                 48          $21,992                                    35
# 5                 81          $20,224                                    31
#
#   2 LONGEVITY LONGEVITY 3 NO. OF GENETIC AILMENTS  ... food per lifetime, $  \
# ...

# %%
# drop column
raw_data_df = raw_data_df.drop(columns = ['intelligence category','repetitions to understand new commands',
                                          'obey first command (% of time)','longevity sample size - survey sample size',
                                          'GENETIC DISEASES - congenital ailments: summary / areas affected',
                                          'congenital ailments: summary / areas affected','exclude?',
                                          'most abandoned?','4 LIFETIME COST','price bracket','toys, presents, treats, per year, £',
                                          'pet sitters, per year, £','kennels per year, £','grooming, per year, £',
                                         'vet fees per year, £','one offs, $'])
raw_data_df.head()
# Out:
#                 Dog breed  category  datadog score POPULARITY IN US  \
# 1           Border Collie   herding           3.64               45
# 2          Border Terrier   terrier           3.61               80
# 3                Brittany  sporting           3.54               30
# 4           Cairn Terrier   terrier           3.53               59
# 5  Welsh Springer Spaniel  sporting           3.34              130
#
#   POPULARITY IN US.1 LIFETIME COST, $ 1 INTELLIGENCE (TRAINABILITY) ranking  \
# 1                 39          $20,143                                     1
# 2                 61          $22,638                                    30
# 3                 30          $22,589                                    19
# 4                 48          $21,992                                    35
# 5                 81          $20,224                                    31
#
#   2 LONGEVITY LONGEVITY 3 NO. OF GENETIC AILMENTS  ... highest (US$)  \
# ...

# %%
# drop column
raw_data_df = raw_data_df.drop(columns = ['datadog score','LONGEVITY',
                                          'food per week, average, £','min, £',
                                          'max, £',
                                          'food per week, $',
                                          'food per year, $','Other regular costs, total per lifetime, $',
                                          'total, per year, £'])
raw_data_df.head()
# Out:
#                 Dog breed  category POPULARITY IN US POPULARITY IN US.1  \
# 1           Border Collie   herding               45                 39
# 2          Border Terrier   terrier               80                 61
# 3                Brittany  sporting               30                 30
# 4           Cairn Terrier   terrier               59                 48
# 5  Welsh Springer Spaniel  sporting              130                 81
#
#   LIFETIME COST, $ 1 INTELLIGENCE (TRAINABILITY) ranking 2 LONGEVITY  \
# 1          $20,143                                     1       12.52
# 2          $22,638                                    30       14.00
# 3          $22,589                                    19       12.92
# 4          $21,992                                    35       13.84
# 5          $20,224                                    31       12.49
#
#   3 NO. OF GENETIC AILMENTS 4a average purchase price, US$  \
# ...

# %%
# drop column
raw_data_df = raw_data_df.drop(columns = ['POPULARITY IN US','POPULARITY IN US.1',
                                          '1 INTELLIGENCE (TRAINABILITY) ranking','average purchase price, US$',
                                          'Unnamed: 30','size category','Unnamed: 36','Unnamed: 46','4a average purchase price, US$'])
raw_data_df.head()
# Out:
#                 Dog breed  category LIFETIME COST, $ 2 LONGEVITY  \
# 1           Border Collie   herding          $20,143       12.52
# 2          Border Terrier   terrier          $22,638       14.00
# 3                Brittany  sporting          $22,589       12.92
# 4           Cairn Terrier   terrier          $21,992       13.84
# 5  Welsh Springer Spaniel  sporting          $20,224       12.49
#
#   3 NO. OF GENETIC AILMENTS 4b food costs per year, US$ 5a grooming required   \
# 1                         2                        $324                     2
# 2                         0                        $324                     2
# 3                         0                        $466                     2
# 4                         2                        $324                     2
# 5                         1                        $324                     2
#
#   grooming required  5b suitability for children  suitability for children   \
# ...

# %%
# drop column
raw_data_df = raw_data_df.drop(columns = ['5a grooming required ','grooming required ',
                                          '5b suitability for children ','suitability for children ',
                                          'Unnamed: 24','POPULAR RATING'])
raw_data_df.head()
# Out:
#                 Dog breed  category LIFETIME COST, $ 2 LONGEVITY  \
# 1           Border Collie   herding          $20,143       12.52
# 2          Border Terrier   terrier          $22,638       14.00
# 3                Brittany  sporting          $22,589       12.92
# 4           Cairn Terrier   terrier          $21,992       13.84
# 5  Welsh Springer Spaniel  sporting          $20,224       12.49
#
#   3 NO. OF GENETIC AILMENTS 4b food costs per year, US$ 4 LIFETIME COST, $  \
# 1                         2                        $324             17,404
# 2                         0                        $324             19,575
# 3                         0                        $466             19,503
# 4                         2                        $324             18,965
# 5                         1                        $324             17,492
#
#   average purchase price (US $) lowest (US$) highest (US$)  \
# 1                           623          175          1050
# ...

# %%
# drop column
raw_data_df = raw_data_df.drop(columns = ['4 LIFETIME COST, $','4b food costs per year, US$',
                                          'total  per year, $'])
raw_data_df.head()
# Out:
#                 Dog breed  category LIFETIME COST, $ 2 LONGEVITY  \
# 1           Border Collie   herding          $20,143       12.52
# 2          Border Terrier   terrier          $22,638       14.00
# 3                Brittany  sporting          $22,589       12.92
# 4           Cairn Terrier   terrier          $21,992       13.84
# 5  Welsh Springer Spaniel  sporting          $20,224       12.49
#
#   3 NO. OF GENETIC AILMENTS average purchase price (US $) lowest (US$)  \
# 1                         2                           623          175
# 2                         0                           833          250
# 3                         0                           618          300
# 4                         2                           435          300
# 5                         1                           750          750
#
#   highest (US$) food per lifetime, $
# 1          1050                3,486
# 2          1200                3,898
# ...

# %%
#notes to myself: ranking in -2 in raw_data_df, missing Miniature American Shephard
clean_data_df = raw_data_df.loc[[74,27,36,69,22,87,65,38,14,24,58,31,32,
                 51,48,78,15,104,85,30,11,76,29,47,122,19,
                 10,3,7,1,16,43,53,84,28,109,6,73,68,158,170,20,151,23,9,52,81,97,169]]
clean_data_df
# Out:
#                          Dog breed      category LIFETIME COST, $ 2 LONGEVITY  \
# 74                  French Bulldog  non-sporting          $17,266        9.00
# 27              Labrador Retriever      sporting          $21,299       12.04
# 36                Golden Retriever      sporting          $21,447       12.04
# 69                 German Shepherd       herding          $17,416        9.73
# 22                          Poodle  non-sporting          $21,237       11.95
# 87                         Bulldog  non-sporting          $13,479        6.29
# 65                      Rottweiler       working          $18,886        9.11
# 38                          Beagle         hound          $19,468       12.30
# 14                       Dachshund         hound          $20,113       12.63
# 24      German Shorthaired Pointer      sporting          $25,842       11.46
# 58            Pembroke Welsh Corgi       herding          $23,978       12.25
# ...

# %%
len(clean_data_df)
# Out:
# 49

# %%
clean_data_df = clean_data_df.drop(columns = ['2 LONGEVITY','3 NO. OF GENETIC AILMENTS',
                                         'average purchase price (US $)','lowest (US$)','highest (US$)','food per lifetime, $'])
clean_data_df
# Out:
#                          Dog breed      category LIFETIME COST, $
# 74                  French Bulldog  non-sporting          $17,266
# 27              Labrador Retriever      sporting          $21,299
# 36                Golden Retriever      sporting          $21,447
# 69                 German Shepherd       herding          $17,416
# 22                          Poodle  non-sporting          $21,237
# 87                         Bulldog  non-sporting          $13,479
# 65                      Rottweiler       working          $18,886
# 38                          Beagle         hound          $19,468
# 14                       Dachshund         hound          $20,113
# 24      German Shorthaired Pointer      sporting          $25,842
# 58            Pembroke Welsh Corgi       herding          $23,978
# 31             Australian Shepherd       herding          $21,458
# 32               Yorkshire Terrier           toy          $20,701
# ...

# %%
clean_data_df['LIFETIME COST, $'] = clean_data_df['LIFETIME COST, $'].str.replace(',', '').str.replace('$', '')
clean_data_df.head()
# Out:
#              Dog breed      category LIFETIME COST, $
# 74      French Bulldog  non-sporting            17266
# 27  Labrador Retriever      sporting            21299
# 36    Golden Retriever      sporting            21447
# 69     German Shepherd       herding            17416
# 22              Poodle  non-sporting            21237

# %%
clean_data_df.loc[122,'LIFETIME COST, $']= '13500'
clean_data_df.loc[158,'LIFETIME COST, $']= '14220'
clean_data_df.loc[109,'LIFETIME COST, $']= '26055'
clean_data_df.loc[151,'LIFETIME COST, $']= '23040'
clean_data_df.loc[170,'LIFETIME COST, $']= '26750'
clean_data_df.loc[169,'LIFETIME COST, $']= '17145'
clean_data_df.loc[97,'LIFETIME COST, $']= '18305'
clean_data_df.loc[104,'LIFETIME COST, $']= '21340'
clean_data_df.head()
# Out:
#              Dog breed      category LIFETIME COST, $
# 74      French Bulldog  non-sporting            17266
# 27  Labrador Retriever      sporting            21299
# 36    Golden Retriever      sporting            21447
# 69     German Shepherd       herding            17416
# 22              Poodle  non-sporting            21237

# %%
clean_data_df['LIFETIME COST, $'] = clean_data_df['LIFETIME COST, $'].astype(float)
clean_data_df.head()
# Out:
#              Dog breed      category  LIFETIME COST, $
# 74      French Bulldog  non-sporting           17266.0
# 27  Labrador Retriever      sporting           21299.0
# 36    Golden Retriever      sporting           21447.0
# 69     German Shepherd       herding           17416.0
# 22              Poodle  non-sporting           21237.0

# %%
clean_data_df['LIFETIME COST, $'] = clean_data_df['LIFETIME COST, $'].astype(int)
clean_data_df.head()
# Out:
#              Dog breed      category  LIFETIME COST, $
# 74      French Bulldog  non-sporting             17266
# 27  Labrador Retriever      sporting             21299
# 36    Golden Retriever      sporting             21447
# 69     German Shepherd       herding             17416
# 22              Poodle  non-sporting             21237

# %%
#Miniature American Shephard
american_shephard_row= {
    'Dog breed': 'Miniature American Shephard',
    'category':'Working',
    'LIFETIME COST, $': 17250,
}
american_shephard_df = pd.DataFrame([american_shephard_row])
american_shephard_df
# Out:
#                      Dog breed category  LIFETIME COST, $
# 0  Miniature American Shephard  Working             17250

# %%
full_clean_data_df = pd.concat([clean_data_df, american_shephard_df], ignore_index=True)
full_clean_data_df.head()
# Out:
#             Dog breed      category  LIFETIME COST, $
# 0      French Bulldog  non-sporting             17266
# 1  Labrador Retriever      sporting             21299
# 2    Golden Retriever      sporting             21447
# 3     German Shepherd       herding             17416
# 4              Poodle  non-sporting             21237

# %%
full_clean_data_df.dtypes
# Out:
# Dog breed           object
# category            object
# LIFETIME COST, $     int64
# dtype: object

# %%
len(full_clean_data_df)
# Out:
# 50

# %%
bins = [13478, 17902, 22327, 26752]
labels = ['Low','Medium','High']
full_clean_data_df.loc[:, 'lifetime_cost_category']= pd.cut(full_clean_data_df.loc[:, 'LIFETIME COST, $'] , bins=bins, labels=labels)

# %%
full_clean_data_df
# Out:
#                         Dog breed      category  LIFETIME COST, $  \
# 0                  French Bulldog  non-sporting             17266
# 1              Labrador Retriever      sporting             21299
# 2                Golden Retriever      sporting             21447
# 3                 German Shepherd       herding             17416
# 4                          Poodle  non-sporting             21237
# 5                         Bulldog  non-sporting             13479
# 6                      Rottweiler       working             18886
# 7                          Beagle         hound             19468
# 8                       Dachshund         hound             20113
# 9      German Shorthaired Pointer      sporting             25842
# 10           Pembroke Welsh Corgi       herding             23978
# 11            Australian Shepherd       herding             21458
# 12              Yorkshire Terrier           toy             20701
# ...

# %%
len(full_clean_data_df)
# Out:
# 50

# %%
#Convert to CSV
full_clean_data_df.to_csv('dog_lifetime_cost.csv')
